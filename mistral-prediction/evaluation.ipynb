# %%
import pandas as pd
import json

df = pd.read_pickle('mistral_results.pkl')
df['hate_speach_probability'][0]



json_string = '{ \n  "relevant_facts": ["The speaker mentions a neighborhood and expresses a dislike for it."],\n  "contained_explicit_hate_speech_vocabular": [],\n  "argument_for_hate_speech": "The speaker expresses disgust towards the children in a specific neighborhood, implying that they are the reason for their dislike.",\n  "argument_against_hate_speech": "The speaker does not directly reference a specific racial or ethnic group, and their dislike is stated towards the neighborhood and its children rather than the children themselves.",\n  "likelihood_of_presence_of_implicit_hate_speech": 0.31,\n  "likelihood_of_presence_of_explicit_hate_speech": 0.05,\n  "likelihood_of_ad_hominem_attack": 0.2,\n  "likelihood_of_minority_attack": 0.1,\n  "likelyhood_of_takedown_on_social_media": 0.3,\n  "hate_speech_probability": 0.12\n}'

# Parse the JSON string
data = json.loads(json_string)
import re
re.compile(r"")
df["prediction"]=df["cz"].apply(lambda x: false if x>0.5 else 0)
# Now data is a Python dictionary. You can access its elements like this:
print(data["relevant_facts"])
print(data["hate_speech_probability"])
# Out:
# ['The speaker mentions a neighborhood and expresses a dislike for it.']
# 0.12

# %%
df
# Out:
#        model                       time           promt_hash  \
# 0    mistral 2024-01-08 14:38:05.853924 -3450054670443982230
# 1    mistral 2024-01-08 14:38:08.705325 -3450054670443982230
# 2    mistral 2024-01-08 14:38:11.671321 -3450054670443982230
# 3    mistral 2024-01-08 14:38:14.178242 -3450054670443982230
# 4    mistral 2024-01-08 14:38:17.956391 -3450054670443982230
# ..       ...                        ...                  ...
# 473  mistral 2024-01-08 15:03:15.635152 -3450054670443982230
# 474  mistral 2024-01-08 15:03:19.517581 -3450054670443982230
# 475  mistral 2024-01-08 15:03:22.517999 -3450054670443982230
# 476  mistral 2024-01-08 15:03:25.285063 -3450054670443982230
# 477  mistral 2024-01-08 15:03:27.666654 -3450054670443982230
#
#                                                 prompt  \
# 0    \nYou are Sally and your job is to be an AI Cl...
# 1    \nYou are Sally and your job is to be an AI Cl...
# 2    \nYou are Sally and your job is to be an AI Cl...
# ...

# %%
from sklearn.metrics import roc_auc_score, log_loss, brier_score_loss

# Assuming y_true is your array of true labels and y_pred is your array of predicted probabilities
y_true = merged_df['label']
y_pred = merged_df['prediction']

roc_auc = roc_auc_score(y_true, y_pred)
logloss = log_loss(y_true, y_pred)
brier_score = brier_score_loss(y_true, y_pred)

print(f"ROC AUC Score: {roc_auc}")
print(f"Log Loss: {logloss}")
print(f"Brier Score: {brier_score}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27124/2180025761.py in <module>
#       2
#       3 # Assuming y_true is your array of true labels and y_pred is your array of predicted probabilities
# ----> 4 y_true = merged_df['label']
#       5 y_pred = merged_df['prediction']
#       6
#
# NameError: name 'merged_df' is not defined

# %%
processed_data_df = pd.read_pickle('processed_data.pkl')

merged_df = pd.merge(data_df, processed_data_df, on='text')
